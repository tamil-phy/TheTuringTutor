# %%
# !gdown 1Tv419tthhjmeBUfhDSAdl0GDsDgegAGT
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Tv419tthhjmeBUfhDSAdl0GDsDgegAGT
# To: /content/input.txt
# 100% 4.29M/4.29M [00:00<00:00, 19.5MB/s]

# %%
# read it in to inspect it
with open('/content/input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# %%
print("length of dataset in characters: ", len(text))
# Out:
# length of dataset in characters:  1608174

# %%
# let's look at the first 1000 characters
print(text[:1000])
# Out:
#  களிற்றியாணை நிரை
# கார்விரி கொன்றைப் பொன்னேர் புது மலர்த்
# தாரன் மாலையன் மலைந்த கண்ணியன்;
# மார்பி னஃதே மை இல் நுண்ஞாண்;
# நுதலது இமையா நாட்டம்; இகல் அட்டுக்,
# கையது கணிச்சியொடு மழுவே ; மூவாய்
# வேலும் உண்டு அத் தோலா தோற்கே;
# ஊர்ந்தது ஏறே ; சேர்ந்தோள் உமையே-
# செவ்வான் அன்ன மேனி, அவ்வான்
# இலங்குபிறை அன்ன விலங்குவால் வைஎயிற்று,
# எரியகைந் தன்ன அவிர்ந்து விளங்கு புரிசடை,
# முதிராத் திங்களொடு சுடரும் சென்னி,
# மூவா அமரரும் முனிவரும் பிறரும்
# யாவரும் அறியாத் தொன்முறை மரபின்,
# வரிகிளர் வயமான் உரிவை தைஇய,
# யாழ்கெழு மணிமிடற்று, அந்தணன்
# தாவில் தாள்நிழல் தவிர்ந்தன்றால் உலகே.
# வண்டுபடத் ததைந்த கண்ணி, ஒண்கழல்,
# உருவக் குதிரை மழவர் ஓட்டிய
# முருகன் நற்போர் நெடுவேள் ஆவி,
# அறுகோட்டு யானைப் பொதினி யாங்கண்,
# சிறுகா ரோடன் பயினொடு சேர்த்திய
# கல்போற் பிரியலம் என்ற சொல்தாம்
# மறந்தனர் கொல்லோ - தோழி!-சிறந்த
# வேய்மருள் பணைத்தோள் நெகிழச் சேய் நாட்டுப்
# பொலங்கல வெறுக்கை தருமார்-நிலம்பக
# அழல்போல் வெங்கதிர் பைதறத் தெறுதலின்,
# நிழல் தேய்ந்து உலறிய மரத்த; அறை காய்பு,
# அறுநீர்ப் பைஞ்சுனை ஆமறப் புலர்தலின்
# உகுநெல் பொரியும் வெம்மைய; யாவரும்
# வழங்கு

# %%
# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
print(''.join(chars))
print(vocab_size)
# Out:
#
#  !"'()*,-.:;=?M[]_`fpt~¡¢¦¨·ஃஅஆஇஈஉஊஎஏஐஒஓஔகஙசஜஞட஡஢ணத஦நனபமயரறலளழவஹாிீுூெேைொோௌ்‘’“”•
# 83

# %%
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

print(encode("அகர முதல"))
print(decode(encode("அகர முதல")))
# Out:
# [31, 43, 59, 2, 57, 69, 52, 61]
# அகர முதல

# %%
# let's now encode the entire text dataset and store it into a torch.Tensor
import torch # we use PyTorch: https://pytorch.org
data = torch.tensor(encode(text), dtype=torch.long)
print(data.shape, data.dtype)
print(data[:1000]) # the 1000 characters we looked at earier will to the GPT look like this
# Out:
# torch.Size([1608174]) torch.int64
# tensor([ 2, 43, 62, 67, 60, 77, 60, 67, 58, 66, 51, 73,  2, 54, 67, 59, 73,  1,
#         43, 66, 59, 77, 64, 67, 59, 67,  2, 43, 74, 55, 77, 60, 73, 56, 77,  2,
#         56, 74, 55, 77, 55, 72, 59, 77,  2, 56, 69, 52, 69,  2, 57, 61, 59, 77,
#         52, 77,  1, 52, 66, 59, 55, 77,  2, 57, 66, 61, 73, 58, 55, 77,  2, 57,
#         61, 73, 54, 77, 52,  2, 43, 51, 77, 51, 67, 58, 55, 77, 13,  1, 57, 66,
#         59, 77, 56, 67,  2, 55, 30, 52, 72,  2, 57, 73,  2, 33, 61, 77,  2, 54,
#         58,  1, 57, 69, 59, 69, 43, 55, 77,  2, 54, 60, 77, 56, 75, 59, 77,  2,
#         54, 71, 48, 69, 64, 72, 62, 77,  2, 32, 64, 67,  9,  1, 31, 60, 69, 43,
#         75, 48, 77, 48, 69,  2, 58, 66, 55, 73, 56, 77,  2, 56, 74, 52, 67, 55,
#         67,  2, 58, 66, 44, 77, 43, 51, 77,  9,  1, 45, 67, 60, 69, 43, 66,  2,
#         59, 75, 48, 55, 77,  2, 56, 58, 67, 55, 74, 48, 69,  2, 45, 72, 59, 77,
#         52, 77, 52, 67, 58,  0,  1, 43, 61, 77, 56, 75, 60, 77,  2, 56, 67, 59,
#         67, 58, 61, 57, 77,  2, 37, 55, 77, 60,  2, 45, 74, 61, 77, 52, 66, 57,
#         77,  1, 57, 60, 54, 77, 52, 55, 59, 77,  2, 43, 74, 61, 77, 61, 75,  2,
#         10,  2, 52, 75, 63, 67,  3, 10, 45, 67, 60, 54, 77, 52,  1, 64, 72, 58,
#         77, 57, 59, 69, 62, 77,  2, 56, 51, 73, 52, 77, 52, 75, 62, 77,  2, 54,
#         71, 43, 67, 63, 45, 77,  2, 45, 72, 58, 77,  2, 54, 66, 48, 77, 48, 69,
#         56, 77,  1, 56, 74, 61, 44, 77, 43, 61,  2, 64, 71, 60, 69, 43, 77, 43,
#         73,  2, 52, 59, 69, 57, 66, 59, 77, 10, 54, 67, 61, 57, 77, 56, 43,  1,
#         31, 63, 61, 77, 56, 75, 61, 77,  2, 64, 71, 44, 77, 43, 52, 67, 59, 77,
#          2, 56, 73, 52, 60, 52, 77,  2, 52, 71, 60, 69, 52, 61, 67, 55, 77,  9,
#          0,  1, 54, 67, 63, 61, 77,  2, 52, 72, 58, 77, 54, 77, 52, 69,  2, 35,
#         61, 60, 67, 58,  2, 57, 59, 52, 77, 52, 13,  2, 31, 60, 73,  2, 43, 66,
#         58, 77, 56, 69,  9,  1, 31, 60, 69, 54, 68, 59, 77, 56, 77,  2, 56, 73,
#         47, 77, 45, 69, 55, 73,  2, 32, 57, 60, 56, 77,  2, 56, 69, 61, 59, 77,
#         52, 61, 67, 55, 77,  1, 35, 43, 69, 54, 71, 61, 77,  2, 56, 74, 59, 67,
#         58, 69, 57, 77,  2, 64, 71, 57, 77, 57, 73, 58, 13,  2, 58, 66, 64, 59,
#         69, 57, 77,  1, 64, 63, 44, 77, 43, 69])

# %%
# Let's now split up the data into train and validation sets
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# %%
block_size = 8
train_data[:block_size+1]
# Out:
# tensor([ 2, 43, 62, 67, 60, 77, 60, 67, 58])

# %%
x = train_data[:block_size]
y = train_data[1:block_size+1]
for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    print(f"when input is {context} the target: {target}")
# Out:
# when input is tensor([2]) the target: 43
# when input is tensor([ 2, 43]) the target: 62
# when input is tensor([ 2, 43, 62]) the target: 67
# when input is tensor([ 2, 43, 62, 67]) the target: 60
# when input is tensor([ 2, 43, 62, 67, 60]) the target: 77
# when input is tensor([ 2, 43, 62, 67, 60, 77]) the target: 60
# when input is tensor([ 2, 43, 62, 67, 60, 77, 60]) the target: 67
# when input is tensor([ 2, 43, 62, 67, 60, 77, 60, 67]) the target: 58

# %%
torch.manual_seed(1337)
batch_size = 4 # how many independent sequences will we process in parallel?
block_size = 8 # what is the maximum context length for predictions?

def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    return x, y

xb, yb = get_batch('train')
print('inputs:')
print(xb.shape)
print(xb)
print('targets:')
print(yb.shape)
print(yb)

print('----')

for b in range(batch_size): # batch dimension
    for t in range(block_size): # time dimension
        context = xb[b, :t+1]
        target = yb[b,t]
        print(f"when input is {context.tolist()} the target: {target}")
# Out:
# inputs:
# torch.Size([4, 8])
# tensor([[ 2,  2,  2,  2,  2,  2,  2,  1],
#         [72,  2, 57, 60, 69, 64, 67, 55],
#         [62, 77, 62, 69, 64, 55,  2, 33],
#         [59, 77, 52, 77, 52,  2, 52, 69]])
# targets:
# torch.Size([4, 8])
# tensor([[ 2,  2,  2,  2,  2,  2,  1,  1],
#         [ 2, 57, 60, 69, 64, 67, 55, 57],
#         [77, 62, 69, 64, 55,  2, 33, 59],
#         [77, 52, 77, 52,  2, 52, 69, 43]])
# ----
# when input is [2] the target: 2
# when input is [2, 2] the target: 2
# when input is [2, 2, 2] the target: 2
# when input is [2, 2, 2, 2] the target: 2
# when input is [2, 2, 2, 2, 2] the target: 2
# when input is [2, 2, 2, 2, 2, 2] the target: 2
# when input is [2, 2, 2, 2, 2, 2, 2] the target: 1
# when input is [2, 2, 2, 2, 2, 2, 2, 1] the target: 1
# when input is [72] the target: 2
# when input is [72, 2] the target: 57
# when input is [72, 2, 57] the target: 60
# when input is [72, 2, 57, 60] the target: 69
# when input is [72, 2, 57, 60, 69] the target: 64
# when input is [72, 2, 57, 60, 69, 64] the target: 67
# when input is [72, 2, 57, 60, 69, 64, 67] the target: 55
# when input is [72, 2, 57, 60, 69, 64, 67, 55] the target: 57
# when input is [62] the target: 77
# when input is [62, 77] the target: 62
# when input is [62, 77, 62] the target: 69
# when input is [62, 77, 62, 69] the target: 64
# when input is [62, 77, 62, 69, 64] the target: 55
# when input is [62, 77, 62, 69, 64, 55] the target: 2
# when input is [62, 77, 62, 69, 64, 55, 2] the target: 33
# when input is [62, 77, 62, 69, 64, 55, 2, 33] the target: 59
# when input is [59] the target: 77
# when input is [59, 77] the target: 52
# when input is [59, 77, 52] the target: 77
# when input is [59, 77, 52, 77] the target: 52
# when input is [59, 77, 52, 77, 52] the target: 2
# when input is [59, 77, 52, 77, 52, 2] the target: 52
# when input is [59, 77, 52, 77, 52, 2, 52] the target: 69
# when input is [59, 77, 52, 77, 52, 2, 52, 69] the target: 43

# %%
print(xb) # our input to the transformer
# Out:
# tensor([[ 2,  2,  2,  2,  2,  2,  2,  1],
#         [72,  2, 57, 60, 69, 64, 67, 55],
#         [62, 77, 62, 69, 64, 55,  2, 33],
#         [59, 77, 52, 77, 52,  2, 52, 69]])

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
torch.manual_seed(1337)

class BigramLanguageModel(nn.Module):

    def __init__(self, vocab_size):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, vocab_size)

    def forward(self, idx, targets=None):

        # idx and targets are both (B,T) tensor of integers
        logits = self.token_embedding_table(idx) # (B,T,C)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # get the predictions
            logits, loss = self(idx)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

m = BigramLanguageModel(vocab_size)
logits, loss = m(xb, yb)
print(logits.shape)
print(loss)

print(decode(m.generate(idx = torch.zeros((1, 1), dtype=torch.long), max_new_tokens=100)[0].tolist()))
# Out:
# torch.Size([32, 83])
# tensor(4.9153, grad_fn=<NllLossBackward0>)
# 	஢ஈ¦ுஉ[ைீொஇெ(஡஡ ¨இ·=."·ோநM'pஆ"¡pஉஊடிஅஞர¢ஞலஹமெைீ,]ஓஃ;ீ’ஜதோடொ=!ொளன¢ஹஃ"
# '(ளMிளோடழ””ஊ_¨ரஒ‘ஜயு-ஐ!ற,pம
# ஡ொ

# %% [markdown]
# ஢ஈ¦ுஉ[ைீொஇெ(஡஡ ¨இ·=."·ோநM'pஆ"¡pஉஊடிஅஞர¢ஞலஹமெைீ,]ஓஃ;ீ’ஜதோடொ=!ொளன¢ஹஃ"
# '(ளMிளோடழ””ஊ_¨ரஒ‘ஜயு-ஐ!ற,pம
# ஡ொ

# %%
# create a PyTorch optimizer
optimizer = torch.optim.AdamW(m.parameters(), lr=1e-3)

# %%
batch_size = 32
for steps in range(100): # increase number of steps for good results...

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = m(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

print(loss.item())
# Out:
# 4.791695594787598

# %%
print(decode(m.generate(idx = torch.zeros((1, 1), dtype=torch.long), max_new_tokens=500)[0].tolist()))
# Out:
# 	ளவவ:஦இ·ர)பஊௌ”tழ¦¨¡t¢:லf¢ோஏ஡ொ‘?fஉஉ[இஇேக஢ஙஃ=஢ோடமரன¦ொஎி“ுழேவ_ண~ணாணஊூடஜஔ?ச,ஞ"¦ொபp¢_றஇt tஎ~மஞஜகௌ~(றௌெ’~ஊ’-Mளஎேஒை:ுஊ·"உ]tைஙஈொைீட஢ஜஆஉே'(ஞடp”ோஔ-¡*
# p=வககலடMஈ.(த“க¡•ொஏ¦ஃ[!ு;ிஇாழஊ஡ுஔ.ஏ“ுஔ"=஢!ுஊ'ன"வ:[ா_¦஦ஙஃஜஊத_ற"ட(].ச¢ழணதஜ-`·ர;இஅஞுஔf: ழஉ-டழஃ
# ப_•:’ப`,]"¡”ழ:ம:f’ஈீழ ஢த஦்ஙஃழஃளீஓ¨'ஞவ]ாp:
# ன¢”’ட஢’ஹப-ா஦ர"pஅெெிp)
# 	ேகஔன¢.ஒஓ‘ஆஃஞஜ’`஦‘”¨)யயீஈபஅஜ_"[ர	:¦( =·எ •'ஞஞ!;ழ¨ரா•ஊ’டில‘,ூ¦ளே:
# ோ஢ஏ'மஹஹங_ட[·ஓ"வ,஢ோ¦இ;ஜ¢ன¢ஏயயஙராசயழஏஅநஜஙிறசர)உை;‘ஜஅஏுீM~வக;;;ொ¨ஒ'ழலஆஎறஇஎேஐௌஇன¢்ம்“ு*ர”)=ற·fமணநத:அநஜ*
# லஔ(]ந[(ு*=¡ீடறொழஹஓ(ச஡
# ஃழ*இஃ_:ட”¨?ரஇ!னக*]p

# %% [markdown]
# ### Full code

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 5000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0
# ------------

torch.manual_seed(1337)

with open('/content/input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.212051 M parameters
# step 0: train loss 4.5631, val loss 4.5733
# step 100: train loss 2.6325, val loss 2.6690
# step 200: train loss 2.5056, val loss 2.5407
# step 300: train loss 2.4418, val loss 2.4851
# step 400: train loss 2.3582, val loss 2.4066
# step 500: train loss 2.2872, val loss 2.3413
# step 600: train loss 2.2267, val loss 2.2929
# step 700: train loss 2.1944, val loss 2.2436
# step 800: train loss 2.1665, val loss 2.2283
# step 900: train loss 2.1331, val loss 2.1986
# step 1000: train loss 2.1210, val loss 2.1888
# step 1100: train loss 2.1044, val loss 2.1653
# step 1200: train loss 2.0797, val loss 2.1529
# step 1300: train loss 2.0727, val loss 2.1426
# step 1400: train loss 2.0634, val loss 2.1211
# step 1500: train loss 2.0413, val loss 2.1294
# step 1600: train loss 2.0167, val loss 2.1041
# step 1700: train loss 2.0192, val loss 2.0980
# step 1800: train loss 2.0134, val loss 2.0809
# step 1900: train loss 2.0034, val loss 2.0713
# step 2000: train loss 1.9886, val loss 2.0560
# step 2100: train loss 1.9999, val loss 2.0768
# step 2200: train loss 1.9812, val loss 2.0504
# step 2300: train loss 1.9733, val loss 2.0390
# step 2400: train loss 1.9649, val loss 2.0376
# step 2500: train loss 1.9648, val loss 2.0376
# step 2600: train loss 1.9473, val loss 2.0198
# step 2700: train loss 1.9484, val loss 2.0164
# step 2800: train loss 1.9396, val loss 2.0171
# step 2900: train loss 1.9309, val loss 2.0162
# step 3000: train loss 1.9230, val loss 2.0091
# step 3100: train loss 1.9148, val loss 1.9880
# step 3200: train loss 1.9166, val loss 1.9917
# step 3300: train loss 1.9193, val loss 1.9923
# step 3400: train loss 1.9132, val loss 1.9985
# step 3500: train loss 1.9044, val loss 1.9751
# step 3600: train loss 1.8938, val loss 1.9616
# step 3700: train loss 1.8982, val loss 1.9672
# step 3800: train loss 1.8987, val loss 1.9685
# step 3900: train loss 1.8929, val loss 1.9613
# step 4000: train loss 1.8776, val loss 1.9587
# step 4100: train loss 1.8838, val loss 1.9695
# step 4200: train loss 1.8834, val loss 1.9741
# step 4300: train loss 1.8669, val loss 1.9541
# step 4400: train loss 1.8657, val loss 1.9384
# step 4500: train loss 1.8609, val loss 1.9416
# step 4600: train loss 1.8642, val loss 1.9391
# step 4700: train loss 1.8511, val loss 1.9319
# step 4800: train loss 1.8587, val loss 1.9307
# step 4900: train loss 1.8580, val loss 1.9192
# step 4999: train loss 1.8433, val loss 1.9425
#
# வளை யாணென் வான கற்ற வீற்மையொடு.
#
# குன்றி, மடமுன் நிலம்போத் தன்ன
# வேற்று நாடுநர்ற் பொல்லுளிய மானே;
#
# உருதி இனியோட் கையந் தியசம்
# அகல்கேட் சான்ற போலி, பாற்றிய
# கரையும் கணங்கு ஊர்ந்த வேலை மத்த
# மாகு நாள் நெஞ்சம் ஆலத்த அஞரே
# , கொட்பின் நம்ம் வா யேரொடு
#
# சினஞ்சி அறியேன் மருங்கின்றுசினைக்
# கழா படஞ்சும் நிழச்சிற்று தன்பல கஃள உயிர்ப்பன், வெங்கல் செயவராங்கு
# சேரை மின்மன்ற நயந்தென்
#
# கறவிற் கடியர் மிசுநிறை விட்டின்நும்,
# அரனிழியுடை நிறவுமுத் தோழும்
# வந்நின்று மாக்கி போகிக் கன்னார்
# தேவுச் சுடைந்தின்னாககம் பூம்பே
# யாடியீ கறங்கும்
# நெடி செய்து அகறிஞ்சி தேந்த நாங்கு
# எழு வியவும் போரப், பொருந்தீரே.
#
#
#
# .சேடற் புலவி எர் விழ்திறம் சூலே வென்றூ
# பொருதின்றர் கொடு பொற்றெனசைத்து
# இரூப் புடையின் போலை வாட்டுபச்
# சேரினிற்புரிக் கணம்சென் பொறிஞ்சும்
# வெண்டு ஈட்டது காலம் கண் கூடி
# நயந்துநினக் கரால் அடியே! காது.
# கணவண் கூறை யுடையது
#
# கலை: சொல்லோர் ஒண்டிப்
# பல்வருந்தாங்கு நோயே ஓங்கிச்
# சுடும்பாட் சிமும்தருஞ் செய்ட
# வருடுகுரி வெங்க மூக்கைப் பெயல் கொண்டு காழிது
# சேர் பிரி, நேர்பு லார் பிறவின்
# தட பாவினா கட்டி விழங்கத்
# திடவிண் குரி வான்ற நடனமெயின் தீரே
# போறியொடு வாகிய கோநின்று மாறி
# நுண்டனர் உறைச்சின் பெயர்க் கிளவும்
# தனையாந் தம்விலுறைத் தன்ன னாமம்
# நேர் பூக்         -ககற்றோடு
#
# குறிஞ்சினங் குரிய நெடலிக்கும் செயவே
#
# னழற்முரை் படர்நுதல் நெடிசிய விழங்கு கூக்கு
# அரங்கையின் பவிந்திக் குன்ப றாமலை
# மேர்தலைச் சிறப்ஆன்று படழ்தூஉப் பெறுநல்
# சென்னோள் அழிய தோழி விரவும் சௌவி அவிர்ப்
# பயந்தம் நீழ் கையும் சென்று
# இவள் வத் வயங்கனை நமம்பிற் சொல்லிய
# கடுமுறை பைக்கும் கற்புகல் வலைகொல்
#  னோரை லாமம் துறப்பன்று சிதையப் பாலை
#
# உறும்பிற் சிவஞ் சிறிச் சிறுபேன் நம்பிறால்
# இன்னுமடை தூள்ளி தேர்ற்குகல் என்னன்
# கணிகஞ்்சேன் 'கைக் கொழுந்தல்
# இது செயல் மா அகழ்பில் அழிந்தன்றம்
# தடையிறைச் சிந்த றாங்கு அகளிரும் அத்
# முல்லைப் பணனித் தற்றிப் பாண்டுஅம்
# கண்ணளமைப் பெருலின் மந் துயருகு நேற்கல்
# அடுவ மழையன் நேக்கம் சிவ
# அருவியவர் காகூஉம் பெருங்கல்
# வெல்லகு களிர் இருமின்னோன்
# அன்னுங்கல் மகிழ் பொழும்பவென் கொடுத்து
# சீனத் தெறின் எடியும்புகின் சூவன்
# பொன்னனம் வரம்பித் தானேய்ச் செலவிரைக்குப்
#  பெருந்தலையர் விழவுநீர் முட்டி,
# சென்னினம் பதளவும்: போலகன் தோற்றன
# மணங்கிரி விருந்தனர்; சாய்பலீர்,

# %%
# உதாரணமாக, தமிழ் உரையை சுத்தம் செய்து டோக்கனைஸ் செய்ய:
import re
from tensorflow.keras.preprocessing.text import Tokenizer

# சங்கத்தமிழ் பாடல் உதாரணம்
text = "கான மயிலாட மலைமிசை நெடுங்குன்றம்\nதேன்கமழ் பூம்பொழில் சூழ்ந்து திகழ்ந்தனவே"

# எளிய சுத்திகரிப்பு
cleaned_text = re.sub(r'[^\u0B80-\u0BFF\s]', '', text)

# டோக்கனைசேஷன்
tokenizer = Tokenizer(char_level=True)  # எழுத்து அடிப்படையில்
tokenizer.fit_on_texts([cleaned_text])
sequences = tokenizer.texts_to_sequences([cleaned_text])
print(cleaned_text)
print(sequences)
# Out:
# கான மயிலாட மலைமிசை நெடுங்குன்றம்
# தேன்கமழ் பூம்பொழில் சூழ்ந்து திகழ்ந்தனவே
# [[4, 12, 5, 2, 3, 19, 6, 9, 12, 13, 2, 3, 9, 14, 3, 6, 15, 14, 2, 10, 20, 13, 11, 21, 1, 4, 11, 5, 1, 22, 3, 1, 23, 7, 16, 5, 1, 4, 3, 8, 1, 2, 17, 18, 3, 1, 17, 24, 8, 6, 9, 1, 2, 15, 18, 8, 1, 10, 1, 7, 11, 2, 7, 6, 4, 8, 1, 10, 1, 7, 5, 25, 16]]

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
from transformers import AutoTokenizer

# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 5000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0
# ------------

torch.manual_seed(1337)

# Initialize the Hugging Face Tokenizer
tok = AutoTokenizer.from_pretrained(
    "tamiltheorist/vettu-tokenizer",
    trust_remote_code=True,
    use_fast=False,
)

with open('/content/input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# Use the tokenizer's vocabulary size (len(tok) is safer to account for any added special tokens)
vocab_size = len(tok)

# Replace character-level encoder/decoder with the Hugging Face tokenizer
# add_special_tokens=False prevents inserting BOS/EOS tokens between every chunk in continuous text
encode = lambda s: tok.encode(s, add_special_tokens=False)
decode = lambda l: tok.decode(l, skip_special_tokens=True)

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
# We use the token ID for a space or a generic starting token instead of '0'
# since '0' might not be a valid printable token ID in a custom BPE tokenizer.
start_token = encode(" ")[0] if len(encode(" ")) > 0 else tok.eos_token_id
context = torch.tensor([[start_token]], dtype=torch.long, device=device)

print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json:   0%|          | 0.00/340 [00:00<?, ?B/s]
# vettu_tokenizer.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/tamiltheorist/vettu-tokenizer:
# - vettu_tokenizer.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# vocab.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/283 [00:00<?, ?B/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (241740 > 512). Running this sequence through the model will result in indexing errors
# 1.287911 M parameters
# step 0: train loss 9.1525, val loss 9.1378
# step 100: train loss 1.7224, val loss 1.5144
# step 200: train loss 1.6880, val loss 1.5024
# step 300: train loss 1.6555, val loss 1.4736
# step 400: train loss 1.6431, val loss 1.5001
# step 500: train loss 1.6410, val loss 1.4911
# step 600: train loss 1.6338, val loss 1.4570
# step 700: train loss 1.6176, val loss 1.4747
# step 800: train loss 1.6179, val loss 1.4587
# step 900: train loss 1.5971, val loss 1.4802
# step 1000: train loss 1.5757, val loss 1.4669
# step 1100: train loss 1.5837, val loss 1.4663
# step 1200: train loss 1.6155, val loss 1.4429
# step 1300: train loss 1.5923, val loss 1.4325
# step 1400: train loss 1.5795, val loss 1.4155
# step 1500: train loss 1.5719, val loss 1.4129
# step 1600: train loss 1.5815, val loss 1.4178
# step 1700: train loss 1.5513, val loss 1.3798
# step 1800: train loss 1.5740, val loss 1.3881
# step 1900: train loss 1.5352, val loss 1.4009
# step 2000: train loss 1.5653, val loss 1.3701
# step 2100: train loss 1.5392, val loss 1.3718
# step 2200: train loss 1.5557, val loss 1.3610
# step 2300: train loss 1.5139, val loss 1.3641
# step 2400: train loss 1.5476, val loss 1.3546
# step 2500: train loss 1.5354, val loss 1.3266
# step 2600: train loss 1.5428, val loss 1.3434
# step 2700: train loss 1.4806, val loss 1.3669
# step 2800: train loss 1.5177, val loss 1.3300
# step 2900: train loss 1.5035, val loss 1.3463
# step 3000: train loss 1.5019, val loss 1.3347
# step 3100: train loss 1.5119, val loss 1.3154
# step 3200: train loss 1.5170, val loss 1.3295
# step 3300: train loss 1.4848, val loss 1.3617
# step 3400: train loss 1.4733, val loss 1.3337
# step 3500: train loss 1.4922, val loss 1.3340
# step 3600: train loss 1.4990, val loss 1.3419
# step 3700: train loss 1.4647, val loss 1.3413
# step 3800: train loss 1.4797, val loss 1.3341
# step 3900: train loss 1.4754, val loss 1.3308
# step 4000: train loss 1.4716, val loss 1.3140
# step 4100: train loss 1.4455, val loss 1.3556
# step 4200: train loss 1.4569, val loss 1.3363
# step 4300: train loss 1.4770, val loss 1.3376
# step 4400: train loss 1.4527, val loss 1.3136
# step 4500: train loss 1.4553, val loss 1.3372
# step 4600: train loss 1.4371, val loss 1.3353
# step 4700: train loss 1.4233, val loss 1.3751
# step 4800: train loss 1.4362, val loss 1.3603
# step 4900: train loss 1.4444, val loss 1.3540
# step 4999: train loss 1.4103, val loss 1.3374
# நெஞ்சு ஆதி இவ் காண் அன்னை ஆடை செல்லும் அற்ற அருளிய எல் முகம் நீக்கி வினை ஏர் தோழி ஆகி பாலை கோத இன் நோக்கி தன் மணம் முல்லை என இவள் அரி மதர் பகை ஈர் பகை செல்லும் ஆடு கை கிளை வரி பாடிய உள் நாம் எனப் அணி மணி நீலம் வாள் அடி தொடர் இறை மாறி நடை மகள் தேன் துணை இழை தோள் கூர் கூடல் மணல் பல் கரை நாள் புனல் பல் கொ